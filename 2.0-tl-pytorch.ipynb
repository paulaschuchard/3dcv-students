# %% [markdown]
# # Exercise 2

# %% [markdown]
# **Please Note**: We updated the requirements.txt
#
# Please install the new requirements before editing this exercise.

# %% [markdown]
# ## Import packages

# %%
import os

from vll.utils.download import download_mnist
import numpy as np
import matplotlib.pyplot as plt

import skimage
import skimage.io

import torch
import torch.nn.functional as F
from torchvision import transforms

from models.mnist.simple_cnn import Net

# %% [markdown]
# ## Task 1
# (2 points)
#
# In this task, you will learn some basic tensor operations using the PyTorch library.
#
# Reference for torch: https://pytorch.org/docs/stable/torch.html

# %%
# Create a numpy array that looks like this: [0, 1, 2, ..., 19]
arr = np.arange(20, dtype=np.float32) 
# Convert the numpy array to a torch tensor
tensor = torch.from_numpy(arr)


# Create a tensor that contains random numbers.
# It should have the same size like the numpy array.
# Multiply it with the previous tensor.
rand_tensor = torch.randn_like(tensor) # torch.randn_like() creates a tensor with the same size as tensor each entry is sample from a normal distribution
tensor = tensor * rand_tensor
print(tensor)

# Create a tensor that contains only 1s.
# It should have the same size like the numpy array.
# Substract it from the previous tensor.
tensor -= torch.full_like(tensor, 1) # torch.full_like() creates a tensor with the same size as tensor each entry is set to 1
print(tensor)

# Get the 5th element using a index.
element = tensor[4] # Indexing in PyTorch is similar to numpy
print(element)

# Create a tensor that contains only 0s.
# It should have the same size like the numpy array.
# Multiply it with the previous tensor without any assignment (in place).
tensor *= 0 # In place operation
# Out:
# tensor([  0.0000,   0.4177,  -1.0187,   3.5670,  -2.9240,   2.6011,  -3.4338,
#           5.7692,  -2.5891, -14.0774, -10.8256, -22.7065,   5.4961,  16.7180,
#         -15.3383,  -7.5097,   6.5552,  21.8746,  19.1137, -16.4027])
# tensor([ -1.0000,  -0.5823,  -2.0187,   2.5670,  -3.9240,   1.6011,  -4.4338,
#           4.7692,  -3.5891, -15.0774, -11.8256, -23.7065,   4.4961,  15.7180,
#         -16.3382,  -8.5097,   5.5552,  20.8746,  18.1137, -17.4027])
# tensor(-3.9240)

# %%
# Load the image from the last exercise as RGB image.
image = skimage.io.imread('./data/pepo.jpg')

# Convert the image to a tensor
print(type(image), image.dtype) # the image is a already a tensor 
image = torch.from_numpy(image).float() # convert the image to a torch tensor

# Print its shape
print(image.shape)

# Flatten the image
image = image.flatten() # flatten the image to a 1D tensor
print(len(image))

# Add another dimension resulting in a 1x78642 tensor
image = image.unsqueeze(0) # unsqueeze adds a dimension at the 0th index
print(image.shape)

# Revert the last action
image = image.squeeze(0) # squeeze removes the dimension at the 0th index
print(image.shape)

# Reshape the tensor, so that it has the original 2D dimensions
image = image.reshape(512, 512, 3) # reshape the image to its original shape
print(image.shape)

# Calculate the sum, mean and max of the tensor
print(torch.sum(image))
print(torch.mean(image))
print(torch.max(image))
# Out:
# <class 'numpy.ndarray'> uint8
# torch.Size([512, 512, 3])
# 786432
# torch.Size([1, 786432])
# torch.Size([786432])
# torch.Size([512, 512, 3])
# tensor(91404848.)
# tensor(116.2273)
# tensor(255.)

# %% [markdown]
# ## Task 2
# (2 points)
#
# Use Autograd to perform operations on a tensor and output then gradients.

# %%
# Create a random 2x2 tensor which requires gradients
x = torch.ones(2, 2, requires_grad=True) 
print(x)

# Create another tensor by adding 2.0
y = x + 2
print(y)

# Create a third tensor z = y^2
z = y**2
print(z, z.requires_grad)

# Compute out as the mean of values in z
out = torch.mean(z)
print(f"{out=}")

# Perform back propagation on out
torch.autograd.backward(out) # out.backward()

# Print the gradients dout/dx
print(x.grad) # the gradient of out with respect to x


# Create a copy of y whithout gradients
y2 = y.detach() 
print(y2.requires_grad)

# Perform the mean operation on z
# with gradients globally disabled
with torch.no_grad():
    out2 = torch.mean(z)
    print(out2.requires_grad) # out2 is not a tensor that requires gradients
    print(out2)
# Out:
# tensor([[1., 1.],
#         [1., 1.]], requires_grad=True)
# tensor([[3., 3.],
#         [3., 3.]], grad_fn=<AddBackward0>)
# tensor([[9., 9.],
#         [9., 9.]], grad_fn=<PowBackward0>) True
# out=tensor(9., grad_fn=<MeanBackward0>)
# tensor([[1.5000, 1.5000],
#         [1.5000, 1.5000]])
# False
# False
# tensor(9.)

# %% [markdown]
# ## Task 3
# (3 points)
#
# Implement a Dataset class for MNIST.

# %%
# We first download the MNIST dataset
download_mnist()
# Out:
# MNIST is ready!

# %%
class MNIST:
    """
    Dataset class for MNIST
    """

    def __init__(self, root, transform=None):
        """
        root -- path to either "training" or "testing"
        
        transform -- transform (from torchvision.transforms)
                     to be applied to the data
        """
        # save transforms
        self.transform = transform
        
        # TODO: create a list of all subdirectories (named like the classes) 
        #       within the dataset root
        self.subdir_paths = [os.path.join(root, str(i)) for i in range(10)]
        
        # TODO: create a list of paths to all images
        #       with the ground truth label
        self.image_paths = [
            (i, file)
            for i in range(10)
            for file in os.listdir(self.subdir_paths[i])
        ]

        
    
    def __len__(self):
        """
        Returns the lenght of the dataset (number of images)
        """
        # TODO: return the length (number of images) of the dataset
        return len(self.image_paths)
        

    def __getitem__(self, index):
        """
        Loads and returns one image as floating point numpy array
        
        index -- image index in [0, self.__len__() - 1]
        """
        # TODO: load the ith image as an numpy array (dtype=float32)
        ground_truth, image_path = self.image_paths[index]
        image = skimage.io.imread(image_path)
        image = image.astype(np.float32)
        
        
        # TODO: apply transforms to the image (if there are any)
        if self.transform:
            self.transform(image)
        
        
        # TODO: return a tuple (transformed image, ground truth)
        return image, ground_truth

# %% [markdown]
# ## Task 4
# (3 points)
#
# You can now load a pretrained neural network model we provide.
# Your last task is to run the model on the MNIST test dataset, plot some example images with the predicted labels and compute the prediction accuracy.

# %%
def validate(model, data_loader):
    # TODO: Create a 10x10 grid of subplots
    fig, axs = plt.subplots(10, 10, figsize=(10, 10))

    model.eval()
    correct = 0 # count for correct predictions
    
    with torch.no_grad():
        for i, item in enumerate(data_loader):
            # TODO: unpack item into image and ground truth
            #       and run network on them
            image, ground_truth = item
            print(image.shape, ground_truth)

            
            
            # TODO: get class with highest probability
            predicted_label = torch.argmax(model(image))
            
            
            # TODO: check if prediction is correct
            #       and add it to correct count
            correct += (predicted_label == ground_truth)
            
            
            # plot the first 100 images
            if i < 100:
                ...
                # TODO: compute position of ith image in the grid
                
                
                # TODO: convert image tensor to numpy array
                #       and normalize to [0, 1]
                
                
                # TODO: make wrongly predicted images red
                
                
                # TODO: disable axis and show image
                
                
                # TODO: show the predicted class next to each image
                
            
            elif i == 100:
                plt.show()
    
    # TODO: compute and print the prediction accuracy in percent
    

# create a DataLoader using the implemented MNIST dataset class
data_loader = torch.utils.data.DataLoader(
    MNIST('data/mnist/testing',
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
    ])),
    batch_size=1, shuffle=True)

# create the neural network
model = Net()

# load the statedict from 'models/mnist/simple_cnn.pt'
model.load_state_dict(torch.load('models/mnist/simple_cnn.pt'))

# validate the model
validate(model, data_loader)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [66], line 67
#      64 model.load_state_dict(torch.load('models/mnist/simple_cnn.pt'))
#      66 # validate the model
# ---> 67 validate(model, data_loader)
#
# Cell In [66], line 9, in validate(model, data_loader)
#       6 correct = 0 # count for correct predictions
#       8 with torch.no_grad():
# ----> 9     for i, item in enumerate(data_loader):
#      10         # TODO: unpack item into image and ground truth
#      11         #       and run network on them
#      12         image, ground_truth = item
#      13         print(image.shape, ground_truth)
#
# File /opt/miniconda3/envs/3dcv-students/lib/python3.10/site-packages/torch/utils/data/dataloader.py:681, in _BaseDataLoaderIter.__next__(self)
#     678 if self._sampler_iter is None:
#     679     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680     self._reset()  # type: ignore[call-arg]
# --> 681 data = self._next_data()
#     682 self._num_yielded += 1
#     683 if self._dataset_kind == _DatasetKind.Iterable and \
#     684         self._IterableDataset_len_called is not None and \
#     685         self._num_yielded > self._IterableDataset_len_called:
#
# File /opt/miniconda3/envs/3dcv-students/lib/python3.10/site-packages/torch/utils/data/dataloader.py:721, in _SingleProcessDataLoaderIter._next_data(self)
#     719 def _next_data(self):
#     720     index = self._next_index()  # may raise StopIteration
# --> 721     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     722     if self._pin_memory:
#     723         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/miniconda3/envs/3dcv-students/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:49, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# File /opt/miniconda3/envs/3dcv-students/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:49, in <listcomp>(.0)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# Cell In [65], line 46, in MNIST.__getitem__(self, index)
#      44 # TODO: load the ith image as an numpy array (dtype=float32)
#      45 ground_truth, image_path = self.image_paths[index]
# ---> 46 image = skimage.io.imread(image_path)
#      47 image = image.astype(np.float32)
#      50 # TODO: apply transforms to the image (if there are any)
#
# File /opt/miniconda3/envs/3dcv-students/lib/python3.10/site-packages/skimage/io/_io.py:48, in imread(fname, as_gray, plugin, **plugin_args)
#      45         plugin = 'tifffile'
#      47 with file_or_url_context(fname) as fname:
# ---> 48     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      50 if not hasattr(img, 'ndim'):
#      51     return img
#
# File /opt/miniconda3/envs/3dcv-students/lib/python3.10/site-packages/skimage/io/manage_plugins.py:207, in call_plugin(kind, *args, **kwargs)
#     203     except IndexError:
#     204         raise RuntimeError('Could not find the plugin "%s" for %s.' %
#     205                            (plugin, kind))
# --> 207 return func(*args, **kwargs)
#
# File /opt/miniconda3/envs/3dcv-students/lib/python3.10/site-packages/skimage/io/_plugins/imageio_plugin.py:10, in imread(*args, **kwargs)
#       8 @wraps(imageio_imread)
#       9 def imread(*args, **kwargs):
# ---> 10     return np.asarray(imageio_imread(*args, **kwargs))
#
# File /opt/miniconda3/envs/3dcv-students/lib/python3.10/site-packages/imageio/__init__.py:97, in imread(uri, format, **kwargs)
#      68 """imread(uri, format=None, **kwargs)
#      69
#      70 Reads an image from the specified file. Returns a numpy array, which
#    (...)
#      86     to see what arguments are available for a particular format.
#      87 """
#      89 warnings.warn(
#      90     "Starting with ImageIO v3 the behavior of this function will switch to that of"
#      91     " iio.v3.imread. To keep the current behavior (and make this warning disappear)"
#    (...)
#      94     stacklevel=2,
#      95 )
# ---> 97 return imread_v2(uri, format=format, **kwargs)
#
# File /opt/miniconda3/envs/3dcv-students/lib/python3.10/site-packages/imageio/v2.py:200, in imread(uri, format, **kwargs)
#     197 imopen_args = decypher_format_arg(format)
#     198 imopen_args["legacy_mode"] = True
# --> 200 with imopen(uri, "ri", **imopen_args) as file:
#     201     return file.read(index=0, **kwargs)
#
# File /opt/miniconda3/envs/3dcv-students/lib/python3.10/site-packages/imageio/core/imopen.py:118, in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     116     request.format_hint = format_hint
#     117 else:
# --> 118     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     120 source = "<bytes>" if isinstance(uri, bytes) else uri
#     122 # fast-path based on plugin
#     123 # (except in legacy mode)
#
# File /opt/miniconda3/envs/3dcv-students/lib/python3.10/site-packages/imageio/core/request.py:248, in Request.__init__(self, uri, mode, extension, format_hint, **kwargs)
#     245     raise ValueError(f"Invalid Request.Mode: {mode}")
#     247 # Parse what was given
# --> 248 self._parse_uri(uri)
#     250 # Set extension
#     251 if extension is not None:
#
# File /opt/miniconda3/envs/3dcv-students/lib/python3.10/site-packages/imageio/core/request.py:407, in Request._parse_uri(self, uri)
#     404 if is_read_request:
#     405     # Reading: check that the file exists (but is allowed a dir)
#     406     if not os.path.exists(fn):
# --> 407         raise FileNotFoundError("No such file: '%s'" % fn)
#     408 else:
#     409     # Writing: check that the directory to write to does exist
#     410     dn = os.path.dirname(fn)
#
# FileNotFoundError: No such file: '/Users/paulaschuchard/versioned/3dcv-students/2441.png'
